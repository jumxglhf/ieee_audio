# %%
import classifier as clf
clf.my_predict("/Users/mingxuanju/Desktop/audio_classifier/src/model.pkl","/Users/mingxuanju/Desktop/Test")
# Out:
# /Users/mingxuanju/anaconda3/lib/python3.6/site-packages/pydub/utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# Analyzing file 1 of 400: /Users/mingxuanju/Desktop/Test/001.wav
# Analyzing file 2 of 400: /Users/mingxuanju/Desktop/Test/002.wav
# Analyzing file 3 of 400: /Users/mingxuanju/Desktop/Test/003.wav
# Analyzing file 4 of 400: /Users/mingxuanju/Desktop/Test/004.wav
# Analyzing file 5 of 400: /Users/mingxuanju/Desktop/Test/005.wav
# Analyzing file 6 of 400: /Users/mingxuanju/Desktop/Test/006.wav
# Analyzing file 7 of 400: /Users/mingxuanju/Desktop/Test/007.wav
# Analyzing file 8 of 400: /Users/mingxuanju/Desktop/Test/008.wav
# Analyzing file 9 of 400: /Users/mingxuanju/Desktop/Test/009.wav
# Analyzing file 10 of 400: /Users/mingxuanju/Desktop/Test/010.wav
# Analyzing file 11 of 400: /Users/mingxuanju/Desktop/Test/011.wav
# ...
