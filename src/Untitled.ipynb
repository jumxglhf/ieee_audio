# %%
import classifier as clf
test_set = "/Users/mingxuanju/Desktop/test"
clf.my_compare(test_set)
# Out:
# /Users/mingxuanju/anaconda3/lib/python3.6/site-packages/pydub/utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# Analyzing file 1 of 227: /Users/mingxuanju/Desktop/test/001.wav
# Analyzing file 2 of 227: /Users/mingxuanju/Desktop/test/003.wav
# Analyzing file 3 of 227: /Users/mingxuanju/Desktop/test/005.wav
# Analyzing file 4 of 227: /Users/mingxuanju/Desktop/test/009.wav
# Analyzing file 5 of 227: /Users/mingxuanju/Desktop/test/010.wav
# Analyzing file 6 of 227: /Users/mingxuanju/Desktop/test/011.wav
# Analyzing file 7 of 227: /Users/mingxuanju/Desktop/test/012.wav
# Analyzing file 8 of 227: /Users/mingxuanju/Desktop/test/015.wav
# Analyzing file 9 of 227: /Users/mingxuanju/Desktop/test/017.wav
# Analyzing file 10 of 227: /Users/mingxuanju/Desktop/test/018.wav
# Analyzing file 11 of 227: /Users/mingxuanju/Desktop/test/019.wav
# ...
